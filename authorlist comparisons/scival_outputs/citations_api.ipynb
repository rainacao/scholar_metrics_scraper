# %%
import os
import requests
import json
import csv
import pandas as pd
from time import sleep
import numpy as np
from pybliometrics.scopus import CitationOverview, AuthorRetrieval, AbstractRetrieval
from pybliometrics.scopus.utils import config
config['Authentication'] ['APIKey'] = "127f5bf5de20d338f686704a9a328b86"
print(config['Authentication'] ['APIKey'])
# Out:
# 127f5bf5de20d338f686704a9a328b86

# %% [markdown]
# ## constants
# publication_cutoff_year refers to the year where publications during and after will be counted
#
# start_year refers to the first year that the publication count will be calculated (first year to be graphed)
#
# end_year refers to the last year that the publication will be calculated (last year to be graphed)

# %%
INPUT_PATH_TO_CSV = "scival_outputs/author_lookup_output.csv"
OUTPUT_PATH_TO_CSV = "scival_dmcbh_citations.csv"
OUTPUT_PATH_TO_CLEANED_CSV = "scival_dmcbh_citations_nodupes.csv"

PUBLICATION_CUTOFF_YEAR = 0 #only publications DURING and AFTER this year will be counted
START_YEAR = 2018
END_YEAR = 2023

# %%
YEARS_INCLUDED = END_YEAR - START_YEAR + 1 #year range count, inclusive

# prepare columns of csv output
output_cols = ["Name", "Scopus ID", "Document Count", "Cited by", "Cited by 5 years", "Publications", "Coauthors", "Affiliation"]

# %% [markdown]
# ### helper functions

# %%
def get_all_citations(documents):
    '''return yearly citation data for all documents for the author'''
    yearly_citations_data = []

    #scopus ID is everything after 2nd hyphen for the eid
    scopus_id_list = [document.eid.split("-",2)[2] for document in documents]
    print(scopus_id_list)

    pages = int(len(documents)/25)
    
    if pages == 0:
        print(f"gathering citations")
        co = CitationOverview(scopus_id_list, start=START_YEAR, end=END_YEAR)
        yearly_citations_data = co.cc
    elif len(documents)%25 == 0:
        # urls = []
        for page in range(pages):
            print(f"gathering citations for page {page}/{pages-1}")
            list_per_page = scopus_id_list[(25*page):(25*(page+1))]
            co = CitationOverview(list_per_page, start=START_YEAR, end=END_YEAR)
            yearly_citations_data = yearly_citations_data + co.cc
            # urls = urls + co.url
    else:
        # urls = []
        for page in range(pages+1):
            print(f"gathering citations for page {page}/{pages}")
            list_per_page = scopus_id_list[(25*page):(25*(page+1))]
            co = CitationOverview(list_per_page, start=START_YEAR, end=END_YEAR)
            yearly_citations_data = yearly_citations_data + co.cc
            # urls = urls + co.url
        
    return yearly_citations_data

# %%
def remove_duplicate_pubs(out_arr):
    eids = []
    new_arr = []
    for i in range(len(out_arr)):
        current_eid = out_arr[i][2]
        if current_eid in eids:
            pass
        else:
            new_arr.append(out_arr[i])
            eids.append(current_eid)
    print("all publications searched")
    return new_arr, eids

# def remove_duplicate_pubs(out_dict):
#     eids = []
#     for i in range(len(out_dict[output_cols[0]])):
#         current_eid = out_dict["eid"][i]
#         if current_eid in eids:
#             #remove everything in that row
#             for key in out_dict.keys():
#                 # print("duplicate found")
#                 out_dict[key].pop(i)
#         else:
#             eids.append(current_eid)
#     print("all publications searched")
#     return out_dict, eids

# %%
def get_document_coauthors(document, author_id, ids_names_dict, coauthor_dict, publications=[]):
    '''document: pybliometrics document object
    author_id: id of author to look for coauthors with
    ids_names_dict: dictionary where key is id and value is author name
    coauthor_dict: dictionary of the document's coauthors'''
    # publications.append(document.title)
    coauthors_list = document.author_ids.split(";")
    if author_id in coauthors_list: coauthors_list.remove(author_id)
    matching_coauthors = list(set(coauthors_list).intersection(ids_names_dict.keys()))
    for id in matching_coauthors:
        coauthor_name = ids_names_dict[id]
        try:
            coauthor_dict[coauthor_name] = coauthor_dict[id] + 1
        except KeyError:
            coauthor_dict[coauthor_name] = 1
    return coauthor_dict

# %%
def fill_article_rows(author_details:tuple, documents, dict):
    '''author_details are (lastname, firstname, author ID)'''
    for document in documents:
        dict[output_cols[0]].append(document.title) #title
        dict[output_cols[1]].append(document.eid) #eid
        dict[output_cols[2]].append(document.coverDate.split("-")[0]) #publication date
        dict[output_cols[3]].append(document.author_names) #author names
        dict[output_cols[4]].append(author_details[0]) #last name
        dict[output_cols[5]].append(author_details[1]) #first name
        dict[output_cols[6]].append(author_details[2]) #author ID

# %% [markdown]
# ## start here
# 1. read the input array that has a column containing author IDs

# %%
member_arr = []
with open(INPUT_PATH_TO_CSV, "r") as f:
    r = csv.reader(f)
    for row in r:
        if row[0] != "":
            member_arr.append(row)

# skip header rows
member_arr = member_arr[1:]
print(len(member_arr))
# Out:
# 128

# %% [markdown]
# 2. filter for only the IDs
# - member_arr_filtered is a 2D array; each row is a new member and each col is that member's information.

# %%
#get members who have ids filled
id_col_idx = 3
lastname_col_idx = 0
firstname_col_idx = 1
print("first row:", member_arr[0])
try:
    member_arr_filtered = [row for row in member_arr if row[id_col_idx] != "" and int(row[id_col_idx])]
except ValueError:
    raise ValueError("make sure the index of the column ID from member array is valid!")
print("first row:", member_arr_filtered[0])
print("number of authors in list:",len(member_arr_filtered))

#subj search in query: 320
# Out:
# first row: ['Abd-Elrahman', 'Khaled', 'University of Ottawa', '36653563400', '0000-0001-9724-1975', 'Learning Memory & Dementias']
# first row: ['Abd-Elrahman', 'Khaled', 'University of Ottawa', '36653563400', '0000-0001-9724-1975', 'Learning Memory & Dementias']
# number of authors in list: 128

# %%
member_ids = [row[id_col_idx] for row in member_arr]
member_names = [f"{member_arr_filtered[i][firstname_col_idx]} {member_arr_filtered[i][lastname_col_idx]}" for i in range(len(member_ids))]
name_id_dict = dict(zip(member_ids, member_names))
print(name_id_dict)
# Out:
# {'36653563400': 'Khaled Abd-Elrahman', '7201584872': 'Douglas Allan', '7004622834': 'Vanessa Auld', '7402093250': 'Jehannine Austin', '6506673405': 'Shelina Babul', '7005627810': 'Shernaz Bamji', '7402080727': 'Phil Barker', '57020811700': 'Steven Barnes', '35474239200': 'Alasdair Barr', '57026954300': 'Jason Barton', '7102979717': 'Clare Beasley', '7101895712': 'Lara Boyd', '16169124200': 'Neil Cashman', '37036981000': 'Mark Cembrowski', '56521302100': 'Trisha Chakrabarty', '55491054000': 'Annie Ciernia', '56009858300': 'Luke Clark', '7201507943': 'Ann-Marie Craig', '36237882900': 'Silke Cresswell', '6603629883': 'Peter Cripton', '35576627400': 'Max Cynader', '7004268181': "Ryan D'Arcy", '7102727063': 'Adele Diamond', '7005866700': 'Doris Doudet', '23004179900': 'Lauren Emberson', '8042510100': 'Thalia Field', '6701799130': 'Stan Floresco', '7004625596': 'Dean Foti', '7004549374': 'Sophia Frangou', '7004079043': 'Liisa Galea', '6603734160': 'Debbie Giaschi', '57191035886': 'Julien Gibon', '7006144166': 'Daniel Goldowitz', '7402800449': 'Michael Gordon', '55666685100': 'Ruth Grunau', '55554765000': 'Kurt Haas', '24467768400': 'Ilker Hacihaliloglu', '55659996000': 'Amani Hariri', '7005268846': 'Sherri Hayden', '6603313142': 'Anthony Herdman', '55148461400': 'Brett Hilton', '7005203713': 'Robin Hsiung', '55633182300': 'Tao Huan', '7003845298': 'Judy Illes', '26434708900': 'Hee Yeon Im', '7005219431': 'Wilfred Jefferies', '14060234300': 'Kamyar Keramatian', '13104405000': 'Shannon Kolind', '7103188726': 'Piotr Kozlowski', '24722578700': 'John Kramer', '56289658200': 'Sarah Kraeutner', '7004476406': 'Charles Krieger', '7102636323': 'Ujendra Kumar', '21742966400': 'Raymond Lam', '7202377295': 'Donna Lang', '6505982349': 'Cornelia Laule', '7005869634': 'Blair Leavitt', '26653630000': 'Duncan Leitch', '7405320868': 'David Li', '6603112417': 'Teresa Liu-Ambrose', '16407421900': 'Ian Mackenzie', '7006717711': 'Brian MacVicar', '35146488900': 'Manu Madhav', '7006759777': 'Joanne Matsubara', '57203029860': 'Benjamin Matthews', '7005375626': 'Martin McKeown', '7006410152': 'Erin Michalak', '7401771256': 'Freda Miller', '55476786100': 'Steven Miller', '15834999500': 'Kota Mizumoto', '7005847836': 'Robert Molday', '6603648444': 'Hakima Moukhles', '6701581292': 'Orson Moritz', '7401632487': 'Tim Murphy', '26039391300': 'Haakon Nygaard', '7402142583': "Timothy O'Connor", '16936616300': 'Joel Oger', '23089215400': 'Ipek Oruc', '35732198900': 'Daniela Palombo', '55305981100': 'William Panenka', '7004159655': 'Paul Pavlidis', '19435899100': 'Steven Pelech', '7401658611': 'Anthony Phillips', '6507466238': 'Mahmoud Pouladi', '8968134400': 'Jacqueline Quandt', '21934612800': 'Manon Ranger', '7007032941': 'Catharine Rankin', '23390344400': 'Alexander Rauscher', '7102737545': 'Lynn Raymond', '26536697200': 'Heather Robertson', '55216196900': 'Julie Robillard', '55252403200': 'Jessica Rosin', '55889287500': 'Jane Roskams', '7006895707': 'Christian Schütz', '7003907622': 'Jeremy Seamans', '6603557927': 'Mypinder Sekhon', '18438336300': 'Noah Silverberg', '35408131500': 'Terry Snutch', '28167863900': 'Jason Snyder', '7005934914': 'Kiran Soma', '7401655359': 'Weihong Song', '56276238300': 'Vesna Sossi', '57203220428': 'Miriam Spering', '54414801200': 'Evelyn Stewart', '7004896118': 'Jon Stoessl', '7005605583': 'Robert Stowe', '7102872243': 'Sriram Subramaniam', '7006808600': 'Roger Tam', '7006262846': 'Wolfram Tetzlaff', '15835979600': 'Rebecca Todd', '6506375023': 'Tony Traboulsee', '6603148038': 'Helen Tremlett', '24177629100': 'Tamara Vanderwal', '56265931000': 'Paul van Donkelaar', '6701641675': 'Victor Viau', '26538354800': 'Daniel Vigo', '55901182300': 'Carles Vilarino-Guell', '24279161600': 'Fidel Vila-Rodriguez', '6602934805': 'Naznin Virji-Babul', '57226701449': 'Yu Tian Wang', '7201849724': 'Lawrence Ward', '57196186173': 'Alexander Weber', '7004200421': 'Cheryl Wellington', '7004687515': 'Janet Werker', '56232410100': 'Christopher West', '5720 ...

# %% [markdown]
# 3. get all the documents from the list of author IDs

# %%
output_dict = {f"{col_name}":[] for col_name in output_cols}
all_citations = [] #all citation per year information will be stored here

names = []
ids = []
coauthors = []

for member in member_arr_filtered:
    sleep(1)
    #create variables of interest
    
    
    lastname = member[lastname_col_idx]
    firstname = member[firstname_col_idx]
    scopus_id = member[id_col_idx]
    
    author_name = f"{firstname} {lastname}"
    coauthor_count = {}

    print(f"looking up {firstname} {lastname} ({scopus_id})...")
    documents = AuthorRetrieval(scopus_id).get_documents()

    #get documents that are older than PUBLICATION CUTOFF YEAR
    adjusted_docs = [document for document in documents if int(document.coverDate.split("-")[0]) >= PUBLICATION_CUTOFF_YEAR]
    print(f"found {len(adjusted_docs)} publications between {PUBLICATION_CUTOFF_YEAR} and now")

    if len(adjusted_docs) == 0:
        print("no documents found in year range")
        continue
    else:
        coauthor_dict = {}
        for document in documents:
            coauthor_dict = get_document_coauthors(document, scopus_id, name_id_dict, coauthor_dict)
        names.append(author_name)
        ids.append(scopus_id)
        coauthors.append(coauthor_dict)
        # get all citations data
        # citations_data = get_all_citations(adjusted_docs)
        # author_citations = [[citation[year][1] for year in range(YEARS_INCLUDED)] for citation in citations_data]
        # all_citations = all_citations + author_citations #all citations keeps track of all the citations in the whole document
        
        # author_details = (lastname, firstname, mem_id)
        # fill_article_rows(author_details, adjusted_docs, output_dict)
        print("done\n")
# Out:
# looking up Khaled Abd-Elrahman (36653563400)...
# found 34 publications between 0 and now
# done
#
# looking up Douglas Allan (7201584872)...
# found 44 publications between 0 and now
# done
#
# looking up Vanessa Auld (7004622834)...
# found 48 publications between 0 and now
# done
#
# looking up Jehannine Austin (7402093250)...
# found 152 publications between 0 and now
# done
#
# looking up Shelina Babul (6506673405)...
# found 53 publications between 0 and now
# done
#
# looking up Shernaz Bamji (7005627810)...
# found 44 publications between 0 and now
# done
#
# looking up Phil Barker (7402080727)...
# found 119 publications between 0 and now
# done
#
# looking up Steven Barnes (57020811700)...
# found 29 publications between 0 and now
# done
#
# looking up Alasdair Barr (35474239200)...
# found 218 publications between 0 and now
# done
#
# looking up Jason Barton (57026954300)...
# found 2 publications between 0 and now
# done
#
# looking up Clare Beasley (7102979717)...
# found 49 publications between 0 and now
# done
#
# looking up Lara Boyd (7101895712)...
# found 217 publications between 0 and now
# done
#
# looking up Neil Cashman (16169124200)...
# found 252 publications between 0 and now
# done
#
# looking up Mark Cembrowski (37036981000)...
# found 24 publications between 0 and now
# done
#
# looking up Trisha Chakrabarty (56521302100)...
# found 44 publications between 0 and now
# done
#
# looking up Annie Ciernia (55491054000)...
# found 28 publications between 0 and now
# done
#
# looking up Luke Clark (56009858300)...
# found 250 publications between 0 and now
# done
#
# looking up Ann-Marie Craig (7201507943)...
# found 114 publications between 0 and now
# done
#
# looking up Silke Cresswell (36237882900)...
# found 46 publications between 0 and now
# done
#
# looking up Peter Cripton (6603629883)...
# found 179 publications between 0 and now
# done
#
# looking up Max Cynader (35576627400)...
# found 227 publications between 0 and now
# done
#
# looking up Ryan D'Arcy (7004268181)...
# found 82 publications between 0 and now
# done
#
# looking up Adele Diamond (7102727063)...
# found 90 publications between 0 and now
# done
#
# looking up Doris Doudet (7005866700)...
# found 133 publications between 0 and now
# done
#
# looking up Lauren Emberson (23004179900)...
# found 49 publications between 0 and now
# done
#
# looking up Thalia Field (8042510100)...
# found 162 publications between 0 and now
# done
#
# looking up Stan Floresco (6701799130)...
# found 152 publications between 0 and now
# done
#
# looking up Dean Foti (7004625596)...
# found 14 publications between 0 and now
# done
#
# looking up Sophia Frangou (7004549374)...
# found 313 publications between 0 and now
# done
#
# looking up Liisa Galea (7004079043)...
# found 210 publications between 0 and now
# done
#
# looking up Debbie Giaschi (6603734160)...
# found 79 publications between 0 and now
# done
#
# looking up Julien Gibon (57191035886)...
# found 25 publications between 0 and now
# done
#
# looking up Daniel Goldowitz (7006144166)...
# found 218 publications between 0 and now
# done
#
# looking up Michael Gordon (7402800449)...
# found 29 publications between 0 and now
# done
#
# looking up Ruth Grunau (55666685100)...
# found 222 publications between 0 and now
# done
#
# looking up Kurt Haas (55554765000)...
# found 55 publications between 0 and now
# done
#
# looking up Ilker Hacihaliloglu (24467768400)...
# found 70 publications between 0 and now
# done
#
# looking up Amani Hariri (55659996000)...
# found 11 publications between 0 and now
# done
#
# looking up Sherri Hayden (7005268846)...
# found 17 publications between 0 and now
# done
#
# looking up Anthony Herdman (6603313142)...
# found 46 publications between 0 and now
# done
#
# looking up Brett Hilton (55148461400)...
# found 20 publications between 0 and now
# done
#
# looking up Robin Hsiung (7005203713)...
# found 227 publications between 0 and now
# done
#
# looking up Tao Huan (55633182300)...
# found 83 publications between 0 and now
# done
#
# looking up Judy Illes (7003845298)...
# found 298 publications between 0 and now
# done
#
# looking up Hee Yeon Im (26434708900)...
# found 19 publications between 0 and now
# done
#
# looking up Wilfred Jefferies (7005219431)...
# found 112 publications between 0 and now
# done
#
# looking up Kamyar Keramatian (14060234300)...
# found 30 publications between 0 and now
# done
#
# looking up Shannon Kolind (13104405000)...
# found 90 publications between 0 and now
# done
#
# looking up Piotr Kozlowski (7103188726)...
# found 139 publications between 0 and now
# done
#
# looking up John Kramer (24722578700)...
# found 112 publications between 0 and now
# done
#
# looking up Sarah Kraeutner (56289658200)...
# found 25 publications between 0 and now
# done
#
# looking up Charles Krieger (7004476406)...
# found 93 publications between 0 and now
# done
#
# looking up Ujendra Kumar (7102636323)...
# found 125 publications between 0 and now
# done
#
# looking up Raymond Lam (21742966400)...
# found 463 publications between 0 and now
# done
#
# looking up Donna Lang (7202377295)...
# found 92 publications between 0 and now
# done
#
# looking up Cornelia Laule (6505982349)...
# found 109 publications between 0 and now
# done
#
# looking up Blair Leavitt (7005869634)...
# found 248 publications between 0 and now
# done
#
# looking up Duncan Leitch (26653630000)...
# found 17 publications between 0 and now
# done
#
# looking up David Li (7405320868)...
# found 175 publications between 0 and now
# done
#
# looking up Teresa Liu-Ambrose (6603112417)...
# found 281 publications between 0 and now
# done
#
# looking up Ian Mackenzie (16407421900)...
# found 282 publications between 0 and now
# done
#
# looking up Brian MacVicar (7006717711)...
# found 167 publications between 0 and now
# done
#
# looking up Manu Madhav (35146488900)...
# found 13 publications between 0 and now
# done
#
# looking up Joanne Matsubara (7006759777)...
# found 105 publications between 0 and now
# done
#
# looking up Benjamin Matthews (57203029860)...
# found 25 publications between 0 and now
# done
#
# looking up Martin McKeown (7005375626)...
# found 260 publications between 0 and now
# done
#
# looking up Erin Michalak (7006410152)...
# found 138 publications between 0 and now
# done
#
# looking up Freda Miller (7401771256)...
# found 196 publications between 0 and now
# done
#
# looking up Steven Miller (55476786100)...
# found 284 publications between 0 and now
# done
#
# looking up Kota Mizumoto (15834999500)...
# found 24 publications between 0 and now
# done
#
# looking up Robert Molday (7005847836)...
# found 217 publications between 0 and now
# done
#
# looking up Hakima Moukhles (6603648444)...
# found 29 publications between 0 and now
# done
#
# looking up Orson Moritz (6701581292)...
# found 55 publications between 0 and now
# done
#
# looking up Tim Murphy (7401632487)...
# found 185 publications between 0 and now
# done
#
# looking up Haakon Nygaard (26039391300)...
# found 42 publications between 0 and now
# done
#
# looking up Timothy O'Connor (7402142583)...
# found 28 publications between 0 and now
# done
#
# looking up Joel Oger (16936616300)...
# found 248 publications between 0 and now
# done
#
# looking up Ipek Oruc (23089215400)...
# found 37 publications between 0 and now
# done
#
# looking up Daniela Palombo (35732198900)...
# found 63 publications between 0 and now
# done
#
# looking up William Panenka (55305981100)...
# found 97 publications between 0 and now
# done
#
# looking up Paul Pavlidis (7004159655)...
# found 158 publications between 0 and now
# done
#
# looking up Steven Pelech (19435899100)...
# found 219 publications between 0 and now
# done
#
# looking up Anthony Phillips (7401658611)...
# found 307 publications between 0 and now
# done
#
# looking up Mahmoud Pouladi (6507466238)...
# found 89 publications between 0 and now
# done
#
# looking up Jacqueline Quandt (8968134400)...
# found 34 publications between 0 and now
# done
#
# looking up Manon Ranger (21934612800)...
# found 39 publications between 0 and now
# done
#
# looking up Catharine Rankin (7007032941)...
# found 111 publications between 0 and now
# done
#
# looking up Alexander Rauscher (23390344400)...
# found 132 publications between 0 and now
# done
#
# looking up Lynn Raymond (7102737545)...
# found 153 publications between 0 and now
# done
#
# looking up Heather Robertson (26536697200)...
# found 13 publications between 0 and now
# done
#
# looking up Julie Robillard (55216196900)...
# found 74 publications between 0 and now
# done
#
# looking up Jessica Rosin (55252403200)...
# found 19 publications between 0 and now
# done
#
# looking up Jane Roskams (55889287500)...
# found 60 publications between 0 and now
# done
#
# looking up Christian Schütz (7006895707)...
# found 107 publications between 0 and now
# done
#
# looking up Jeremy Seamans (7003907622)...
# found 70 publications between 0 and now
# done
#
# looking up Mypinder Sekhon (6603557927)...
# found 118 publications between 0 and now
# done
#
# looking up Noah Silverberg (18438336300)...
# found 122 publications between 0 and now
# done
#
# looking up Terry Snutch (35408131500)...
# found 208 publications between 0 and now
# done
#
# looking up Jason Snyder (28167863900)...
# found 37 publications between 0 and now
# done
#
# looking up Kiran Soma (7005934914)...
# found 129 publications between 0 and now
# done
#
# looking up Weihong Song (7401655359)...
# found 171 publications between 0 and now
# done
#
# looking up Vesna Sossi (56276238300)...
# found 334 publications between 0 and now
# done
#
# looking up Miriam Spering (57203220428)...
# found 47 publications between 0 and now
# done
#
# looking up Evelyn Stewart (54414801200)...
# found 145 publications between 0 and now
# done
#
# looking up Jon Stoessl (7004896118)...
# found 305 publications between 0 and now
# done
#
# looking up Robert Stowe (7005605583)...
# found 21 publications between 0 and now
# done
#
# looking up Sriram Subramaniam (7102872243)...
# found 209 publications between 0 and now
# done
#
# looking up Roger Tam (7006808600)...
# found 114 publications between 0 and now
# done
#
# looking up Wolfram Tetzlaff (7006262846)...
# found 206 publications between 0 and now
# done
#
# looking up Rebecca Todd (15835979600)...
# found 63 publications between 0 and now
# done
#
# looking up Tony Traboulsee (6506375023)...
# found 6 publications between 0 and now
# done
#
# looking up Helen Tremlett (6603148038)...
# found 257 publications between 0 and now
# done
#
# looking up Tamara Vanderwal (24177629100)...
# found 28 publications between 0 and now
# done
#
# looking up Paul van Donkelaar (56265931000)...
# found 113 publications between 0 and now
# done
#
# looking up Victor Viau (6701641675)...
# found 67 publications between 0 and now
# done
#
# looking up Daniel Vigo (26538354800)...
# found 54 publications between 0 and now
# done
#
# looking up Carles Vilarino-Guell (55901182300)...
# found 115 publications between 0 and now
# done
#
# looking up Fidel Vila-Rodriguez (24279161600)...
# found 161 publications between 0 and now
# done
#
# looking up Naznin Virji-Babul (6602934805)...
# found 80 publications between 0 and now
# done
#
# looking up Yu Tian Wang (57226701449)...
# found 12 publications between 0 and now
# done
#
# looking up Lawrence Ward (7201849724)...
# found 159 publications between 0 and now
# done
#
# looking up Alexander Weber (57196186173)...
# found 14 publications between 0 and now
# done
#
# looking up Cheryl Wellington (7004200421)...
# found 164 publications between 0 and now
# done
#
# looking up Janet Werker (7004687515)...
# found 165 publications between 0 and now
# done
#
# looking up Christopher West (56232410100)...
# found 91 publications between 0 and now
# done
#
# looking up Catharine Winstanley (57207534482)...
# found 47 publications between 0 and now
# done
#
# looking up Todd Woodward (7102848867)...
# found 184 publications between 0 and now
# done
#
# looking up Lakshmi Yatham (35431694500)...
# found 431 publications between 0 and now
# done

# %% [markdown]
# 4. format the citations information to append to dictionary, then export as csv

# %%
out_dict = {
    "Name":names,
    "Scopus ID":ids,
    "Coauthors":coauthors,
}

df = pd.DataFrame(out_dict)
df.to_csv(OUTPUT_PATH_TO_CSV)

# %%
for key in output_dict:
    print(f"{key}: {len(output_dict[key])}")
    
citations_array = np.array(all_citations)
citations_array = citations_array.T
# Out:
# title: 4195
# eid: 4195
# publication year: 4195
# authors: 4195
# last name: 4195
# first name: 4195
# member id: 4195

# %%
# check that all the columns have the same length
for key in output_dict:
    print(f"{key}: {len(output_dict[key])}")

# add citations of each year to the citations dictionary
for year in range(YEARS_INCLUDED):
    year_col = START_YEAR + year
    output_dict[str(year_col)] = citations_array[year].tolist()

df = pd.DataFrame(output_dict)
df.to_csv(OUTPUT_PATH_TO_CSV)
# Out:
# title: 4195
# eid: 4195
# publication year: 4195
# authors: 4195
# last name: 4195
# first name: 4195
# member id: 4195
# 2018: 4195
# 2019: 4195
# 2020: 4195
# 2021: 4195
# 2022: 4195
# 2023: 4195

# %% [markdown]
# 4. remove duplicates

# %%
member_arr_filled = []
with open(OUTPUT_PATH_TO_CSV, "r") as f:
    r = csv.reader(f)
    for row in r:
        if row[0] != "":
            member_arr_filled.append(row)

# skip header rows
citations_header = member_arr_filled[0]
member_arr_filled = member_arr_filled[1:]

print("initial number of documents:",len(member_arr_filled))

# remove and store duplicates
no_dupes_arr, eid = remove_duplicate_pubs(member_arr_filled)

print("number of documents after duplicates are removed:",len(no_dupes_arr))

with open(OUTPUT_PATH_TO_CLEANED_CSV, 'w+', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    mywriter.writerow(citations_header)
    mywriter.writerows(no_dupes_arr)
# Out:
# initial number of documents: 4194
# all publications searched
# number of documents after duplicates are removed: 3361

# %%
identifier = "7401632487"
ar = AuthorRetrieval(identifier)

# %%
print(ar.citation_count)

author_dict = {}
author_dict["Citation Count"] =ar.citation_count
print(author_dict)
# Out:
# 14731
# {'Citation Count': 14731}

# %%
pubs = ar.get_documents()

# %%
print(pubs[0].author_ids.split(";"))
# Out:
# ['57217703996', '57204943506', '57211750582', '57211956459', '7401632487']

# %%
documents = ar.get_coauthors()
